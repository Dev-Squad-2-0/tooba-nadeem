# %%
import sys

print(sys.executable)
# Out:
# C:\Users\ahmed\Downloads\Netixsol\Week6\Day28\venv\Scripts\python.exe

# %%
from src.state import AgentState

print("AgentState imported successfully")
# Out:
# AgentState imported successfully

# %%
# from src.router import classify_intent

# query = "Will Collingwood beat Geelong this week?"

# intent = classify_intent(query)

# print("Query:", query)
# print("Intent:", intent)

# %%
# from src.router import classify_intent

# queries = [
#     "Who is Nick Daicos?",
#     "What were Collingwood's results last season?",
#     "Will Collingwood beat Geelong this week?",
#     "What is the weather in Islamabad?",
# ]

# for query in queries:
#     print(f"{query}")
#     print(f"→ {classify_intent(query)}")
#     print()

# %%
# from src.predict import load_match_feature_table

# matches = load_match_feature_table()

# print("Columns:")
# print(matches.columns.tolist())

# print("\nTeam names:")
# teams = sorted(
#     set(matches["home_team"].dropna().unique())
#     | set(matches["away_team"].dropna().unique())
# )

# for team in teams:
#     print(team)

# print("\nDate range:")
# print(matches["match_date"].min())
# print(matches["match_date"].max())
# Out:
# Columns:
# ['match_date', 'round', 'home_team', 'away_team', 'home_career_experience', 'away_career_experience', 'home_days_since_last_match', 'away_days_since_last_match', 'home_goals_last3_avg', 'away_goals_last3_avg', 'home_goals_last5_avg', 'away_goals_last5_avg', 'home_disposals_last3_avg', 'away_disposals_last3_avg', 'home_disposals_last5_avg', 'away_disposals_last5_avg', 'home_fantasy_points_last3_avg', 'away_fantasy_points_last3_avg', 'home_fantasy_points_last5_avg', 'away_fantasy_points_last5_avg', 'home_h2h_win_rate_entering_match', 'away_h2h_win_rate_entering_match', 'home_win']
#
# Team names:
# Adelaide Crows
# Brisbane Bears
# Brisbane Lions
# Carlton Blues
# Collingwood Magpies
# Essendon Bombers
# Fitzroy Lions
# Fremantle Dockers
# Geelong Cats
# Gold Coast Suns
# Greater Western Sydney Giants
# Hawthorn Hawks
# Melbourne Demons
# North Melbourne Kangaroos
# Port Adelaide Power
# Richmond Tigers
# St Kilda Saints
# Sydney Swans
# West Coast Eagles
# Western Bulldogs
# ...
